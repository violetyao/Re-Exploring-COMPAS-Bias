# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import scipy
# from datascience import *
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import json
import os
import seaborn as sns
import pandas as pd
from IPython.display import display
pd.options.display.max_columns = None

# %% [markdown]
# # What our research question is?

# %% [markdown]
# State-of-the-art researches questioning fairness of COMPAS scores mainly focus on racial bias. We are interested in how other factors, such as age, gender, marital status, and sentence type, might also result in biased COMPAS scores.
#
# COMPAS is a black box. We do not really know how the scoring system works: how many features it is using, what exactly are the features, etc.

# %% [markdown]
# # How we collected our data?

# %% [markdown]
# COMPAS itself did not have an open database, but it does have a [technical document]( http://www.northpointeinc.com/files/technical_documents/FieldGuide2_081412.pdf) for how to intepret the scores.
#
# As for COMPAS scores and crime data, we are drawing from a [open sourced project on github done by ProPublica](https://github.com/propublica/compas-analysis). We believe comparing to this, there is no better alternative. Since COMPAS is a black box and is a commercial software, it is challenging for us to request data directly from its developer. We also looked into other researches on COMPAS, but they gave way to ProPublica either because of smaller dataset or less complete inmate profiles.
#
# The ProPublica dataset consists mainly of three files: `compas-scores-raw.csv`, `compas-scores-two-years.csv`, and `compas-scores-two-years-violent.csv`.
#
# Although we do not data ourselves, instead we use data published at [Propublica's github](https://github.com/propublica/compas-analysis), we still try to make sure that the data we use were ethically collected.
#
# ## How ProPublica [collected its data](https://www.propublica.org/article/how-we-analyzed-the-compas-recidivism-algorithm)?
#
# ProPublica's data are from [Broward County](https://en.wikipedia.org/wiki/Broward_County,_Florida) in Florida, which  primarily uses COMPAS scores to determine whether to release or detain a defendant before their trial. ProPublica acquired COMPAS scores by an open request to the developer of COMPAS. As for profiles of inmates, ProPublica accessed through [Broward County Clerk’s Office](https://www.clerk-17th-flcourts.org/Web2/CaseSearch/Results)
#
# By looking into that, we become more confident that our research will not infringe upon citizens' privacy.

# %% [markdown]
# # What additional source did we incorporate?
#
# In addition to data directly acquired from ProPublica, we are using demographic information of Broward county from [2015 5-Year American community Servey](https://www.census.gov/programs-surveys/acs/technical-documentation/table-and-geography-changes/2015/5-year.html#par_textimage_0) and [broward.org](http://www.broward.org/Planning/Demographics/Pages/default.aspx).
#
# ## Demographics - 2015 5-Year American Community Survey:
#
# Households & Families
# As of the 2015 5-year ACS, Broward County had 1,843,152 people, 670,284 households, and 425,680 families. Of the 670,284 households in Broward County, 26.2% had children under the age of 18 living with them, 43% were married couples living together, 15.6% had a female householder with no husband present, and 36.5% were non-families. 29.6% of all households were made up of individuals and 11.6% had someone living alone who was 65 years of age or older. The average household size was 2.73 and the average family size was 3.43.
#
# Age
# In the county, the population was spread out with 21.7% under the age of 18, 8.5% from 18 to 24, 26.9% from 25 to 44, 27.7% from 45 to 64, and 15.0% who were 65 years of age or older. The median age was 40 years. For every 100 females, there were 94.4 males. For every 100 females age 18 and over, there were 98.7 males.
#
# Race, Ancestry & Nationality
# The racial makeup of the county was 62.3% White, 17.1% Hispanic, 12.2% Black or African American, 5.07% Asian, 2.20% from two or more races, 0.66% Native American, 0.16% Pacific Islander, and 0.20% from some other race. The racial makeup of the total Hispanic population in Broward County was: 65.8% White, 5.90% Native American, 2.06% Black or African American, 0.33% Asian, 0.86% Pacific Islander, 26.23% were some other race and 4.57% were from two or more races. In 2015, with relation to ancestry (excluding the various Hispanic and Latino ancestries), 7.38% were Italian, 7.70% American, 6.44% German, 6.54% Irish, 3.8% English, 2.6% Polish and 2.2% Russian ancestry. Also, among West Indians, 6.33% were Haitian and 5.96% were Jamaican. In 2015, 32.2% of the county's population was foreign born, with 18.14% being naturalized American citizens. Of foreign born residents, 78.9% were born in Latin America, 7.88% were born in Europe, 8.52% born in Asia, 3.11% in North America, 1.34% born in Africa and 0.15 were born in Oceania.
#
# 2018 Republican 31.3%  Democratic 67.9%

# %% [markdown]
# # Summary of Our Data

# %%
compas_raw = pd.read_csv('data/compas-scores-raw.csv')

# %%
compas_raw.shape
# Out:
# (60843, 28)

# %% [markdown]
# There are 60843 cases in compas_raw. As for compas_scores_two_years.csv and compas_scores_two_years_violent.csv, there are respectively 7214 and 4743 cases. From 60483 cases in compas_raw, researchers at ProPublica cleaned the data, only kept data of people who were assessed at the pretrial stage, discarding those that were assessed at parole, probation and other stages in criminal justice system.

# %%
compas_raw.head()
# Out:
#    Person_ID  AssessmentID  Case_ID Agency_Text LastName FirstName MiddleName  \
# 0      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 1      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 2      50844         57167    51950    PRETRIAL   Fisher     Kevin        NaN
# 3      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
# 4      50848         57174    51956    PRETRIAL  KENDALL     KEVIN        NaN
#
#   Sex_Code_Text Ethnic_Code_Text DateOfBirth  ScaleSet_ID            ScaleSet  \
# 0          Male        Caucasian    12/05/92           22  Risk and Prescreen
# 1          Male        Caucasian    12/05/92           22  Risk and Prescreen
# 2          Male        Caucasian    12/05/92           22  Risk and Prescreen
# 3          Male        Caucasian    09/16/84           22  Risk and Prescreen
# 4          Male        Caucasian    09/16/84           22  Risk and Prescreen
#
# ...

# %%
compas_raw.columns
# Out:
# Index(['Person_ID', 'AssessmentID', 'Case_ID', 'Agency_Text', 'LastName',
#        'FirstName', 'MiddleName', 'Sex_Code_Text', 'Ethnic_Code_Text',
#        'DateOfBirth', 'ScaleSet_ID', 'ScaleSet', 'AssessmentReason',
#        'Language', 'LegalStatus', 'CustodyStatus', 'MaritalStatus',
#        'Screening_Date', 'RecSupervisionLevel', 'RecSupervisionLevelText',
#        'Scale_ID', 'DisplayText', 'RawScore', 'DecileScore', 'ScoreText',
#        'AssessmentType', 'IsCompleted', 'IsDeleted'],
#       dtype='object')

# %% [markdown]
# #### Features
#
# "Agency_Text" describes the context where people was assessed by COMPAS.
#
# "LastName" and "FirstName" are name infos.
#
# "Sex_Code_Text" gives gender infos.
#
# "Ethnic_Code_Text" gives racial infos.
#
# "DateOfBirth" gives age infos.
#
# "AssessmentReason" are all "intake".
#
# "Language" are either English or Spanish.
#
# "MaritalStatus" describes marital status.
#
# "DecileScore" are in a scale of 1 to 10 and "ScoreText" gives a category based on DecileScore.
#
# While past researches questioning fairness of COMPAS scores focus on racial factor, we want to investigate into other factors such as sex, age, language, marital status, past_crimes, etc.

# %%
compas_raw['Ethnic_Code_Text'].unique()
# Out:
# array(['Caucasian', 'African-American', 'Hispanic', 'Other', 'Asian',
#        'African-Am', 'Native American', 'Oriental', 'Arabic'],
#       dtype=object)

# %% [markdown]
# __Data cleaning__: Change `African-Am` to `African-American`:

# %%
compas_raw.loc[compas_raw['Ethnic_Code_Text'] == 'African-Am', 'Ethnic_Code_Text'] = 'African-American'

# %% [markdown]
# ## Distribution of Sexes

# %%
raw_sex = compas_raw.loc[:,["Sex_Code_Text"]]
raw_sex_grouped = raw_sex.groupby(["Sex_Code_Text"]).size().reset_index()
raw_sex_grouped.columns = ["Sex_Code_Text","count"]
raw_sex_grouped
# Out:
#   Sex_Code_Text  count
# 0        Female  13329
# 1          Male  47514

# %%
plt.pie(raw_sex_grouped['count'], labels=raw_sex_grouped['Sex_Code_Text']);

# %% [markdown]
# Demographic distribution as a comparison:

# %%
plt.pie([100, 98.7], labels=['Female', 'Male']);

# %%
raw_sex_score = compas_raw.loc[:,["Sex_Code_Text","ScoreText"]]
raw_sex_score_grouped = raw_sex_score.groupby(["Sex_Code_Text","ScoreText"]).size().reset_index()
raw_sex_score_grouped.columns = ["Sex_Code_Text","ScoreText","count"]
raw_sex_score_grouped
## how to append a column which works on percentage
raw_sex_score_grouped['percentage'] = 1.0
for i in range(3):
    raw_sex_score_grouped['percentage'][i] = raw_sex_score_grouped['count'][i] / 13329
for i in range(3,6):
    raw_sex_score_grouped['percentage'][i] = raw_sex_score_grouped['count'][i] / 47514

# %%
raw_sex_score_grouped
# Out:
#   Sex_Code_Text ScoreText  count  percentage
# 0        Female      High   1040    0.078025
# 1        Female       Low   9796    0.734939
# 2        Female    Medium   2483    0.186286
# 3          Male      High   5783    0.121711
# 4          Male       Low  31691    0.666982
# 5          Male    Medium  10005    0.210570

# %% [markdown]
# ## Distribution of Races

# %%
raw_ethnic = compas_raw.loc[:,["Ethnic_Code_Text"]]
raw_ethnic_grouped = raw_ethnic.groupby(["Ethnic_Code_Text"]).size().reset_index()
raw_ethnic_grouped.columns = ["Ethnic_Code_Text","count"]
raw_ethnic_grouped
# Out:
#    Ethnic_Code_Text  count
# 0  African-American  27069
# 1            Arabic     75
# 2             Asian    324
# 3         Caucasian  21783
# 4          Hispanic   8742
# 5   Native American    219
# 6          Oriental     39
# 7             Other   2592

# %%
sns.barplot(y = 'Ethnic_Code_Text', x = 'count', data = raw_ethnic_grouped.sort_values('count', ascending=False))
plt.xlabel('Count')
plt.ylabel('Race');

# %% [markdown]
# Demographic distribution as a comparison:

# %%
sns.barplot(x=[12.2, 62.3, 17.1, 2.4, 5.07, 0.82], y=['Black or African American', 'White', 'Hispanic', 'Other', 'Asian', 'Native American or Pacific Islander'])
plt.xlabel('Percent')
plt.ylabel('Race');

# %%
raw_ethnic_score_grouped = compas_raw.groupby(['Ethnic_Code_Text', 'ScoreText']).agg({'ScoreText': 'count'})
raw_ethnic_score_grouped = raw_ethnic_score_grouped.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))
raw_ethnic_score = compas_raw.loc[:,["Ethnic_Code_Text","ScoreText"]]
raw_ethnic_score_grouped = raw_ethnic_score.groupby(["Ethnic_Code_Text","ScoreText"]).size().reset_index()
raw_ethnic_score_grouped.columns = ["Ethnic_Code_Text","ScoreText","count"]
raw_ethnic_score_grouped
# Out:
#     Ethnic_Code_Text ScoreText  count
# 0   African-American      High   4560
# 1   African-American       Low  15485
# 2   African-American    Medium   7008
# 3             Arabic      High      5
# 4             Arabic       Low     58
# 5             Arabic    Medium     12
# 6              Asian      High     14
# 7              Asian       Low    278
# 8              Asian    Medium     32
# 9          Caucasian      High   1648
# 10         Caucasian       Low  16361
# 11         Caucasian    Medium   3756
# 12          Hispanic      High    473
# 13          Hispanic       Low   6963
# 14          Hispanic    Medium   1297
# 15   Native American      High     32
# 16   Native American       Low    140
# 17   Native American    Medium     47
# 18          Oriental      High      2
# 19          Oriental       Low     33
# 20          Oriental    Medium      4
# 21             Other      High     89
# 22             Other       Low   2169
# 23             Other    Medium    332

# %% [markdown]
# Distribution of races on different risk levels:

# %%
sns.barplot(y = 'Ethnic_Code_Text', x = 'count', hue='ScoreText', data = raw_ethnic_score_grouped.sort_values('count', ascending=False))
plt.xlabel('Count')
plt.ylabel('Race')
plt.legend(loc=4);

# %% [markdown]
# ## Distribution of Languages Spoken

# %%
raw_english = compas_raw.loc[:,["Language"]]
raw_english_grouped = raw_english.groupby(["Language"]).size().reset_index()
raw_english_grouped.columns = ["Language","count"]
raw_english_grouped
# Out:
#   Language  count
# 0  English  60591
# 1  Spanish    252

# %%
raw_english_score_grouped = compas_raw.groupby(["Language", 'ScoreText']).agg({'ScoreText': 'count'})
raw_english_score_grouped = raw_english_score_grouped.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))
raw_english_score_grouped
# Out:
#                     ScoreText
# Language ScoreText
# English  High       11.265814
#          Low        68.146533
#          Medium     20.587652
# Spanish  High        0.793651
#          Low        90.079365
#          Medium      9.126984

# %% [markdown]
# __It is worth noticing that spanish speaking has a lower score.__

# %% [markdown]
# ## Distribution of Marital Status

# %%
raw_marriage = compas_raw.loc[:,["MaritalStatus"]]
raw_marriage_grouped = raw_marriage.groupby(["MaritalStatus"]).size().reset_index()
raw_marriage_grouped.columns = ["MaritalStatus","count"]
raw_marriage_grouped
# Out:
#        MaritalStatus  count
# 0           Divorced   3879
# 1            Married   8172
# 2          Separated   1803
# 3  Significant Other   1260
# 4             Single  45126
# 5            Unknown    213
# 6            Widowed    390

# %%
raw_marriage_score_grouped = compas_raw.groupby(["MaritalStatus", 'ScoreText']).agg({'ScoreText': 'count'})
raw_marriage_score_grouped = raw_marriage_score_grouped.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))
raw_marriage_score_grouped
# Out:
#                              ScoreText
# MaritalStatus     ScoreText
# Divorced          High        4.823317
#                   Low        83.930874
#                   Medium     11.245809
# Married           High        3.858875
#                   Low        86.451060
#                   Medium      9.690065
# Separated         High        5.327414
#                   Low        79.633740
#                   Medium     15.038846
# Significant Other High        8.028617
#                   Low        72.019078
#                   Medium     19.952305
# Single            High       13.491518
#                   Low        62.885021
#                   Medium     23.623462
# Unknown           High        3.755869
#                   Low        79.812207
#                   Medium     16.431925
# Widowed           High        8.205128
#                   Low        78.717949
#                   Medium     13.076923

# %% [markdown]
# ## Distribution of Legal Statuses

# %%
raw_legalstatus = compas_raw.loc[:,["LegalStatus"]]
raw_legalstatus_grouped = raw_legalstatus.groupby(["LegalStatus"]).size().reset_index()
raw_legalstatus_grouped.columns = ["LegalStatus","count"]
raw_legalstatus_grouped
# Out:
#            LegalStatus  count
# 0  Conditional Release    420
# 1  Deferred Sentencing     12
# 2                Other   4356
# 3      Parole Violator     18
# 4        Post Sentence  18333
# 5             Pretrial  37578
# 6   Probation Violator    126

# %%
raw_legalstatus_score_grouped = compas_raw.groupby(["LegalStatus", 'ScoreText']).agg({'ScoreText': 'count'})
raw_legalstatus_score_grouped = raw_legalstatus_score_grouped.groupby(level=0).apply(lambda x:
                                                 100 * x / float(x.sum()))
raw_legalstatus_score_grouped
# Out:
#                                ScoreText
# LegalStatus         ScoreText
# Conditional Release High       14.354067
#                     Low        63.875598
#                     Medium     21.770335
# Deferred Sentencing High       16.666667
#                     Low        66.666667
#                     Medium     16.666667
# Other               High        4.805702
#                     Low        79.719476
#                     Medium     15.474822
# Parole Violator     Low        94.444444
#                     Medium      5.555556
# Post Sentence       High        9.225898
#                     Low        71.519817
#                     Medium     19.254285
# Pretrial            High       12.849802
#                     Low        65.439199
#                     Medium     21.710999
# Probation Violator  High       28.571429
#                     Low        39.682540
#                     Medium     31.746032

# %% [markdown]
# ## Distribution of Custody Statuses

# %%
raw_custody = compas_raw.loc[:,["CustodyStatus"]]
raw_custody_grouped = raw_custody.groupby(["CustodyStatus"]).size().reset_index()
raw_custody_grouped.columns = ["CustodyStatus","count"]
raw_custody_grouped
# Out:
#          CustodyStatus  count
# 0          Jail Inmate  30129
# 1               Parole     21
# 2   Pretrial Defendant   7644
# 3        Prison Inmate     15
# 4            Probation  22968
# 5  Residential Program     66

# %%
raw_custody_score_grouped = compas_raw.groupby(["CustodyStatus", 'ScoreText']).agg({'ScoreText': 'count'})
raw_custody_score_grouped = raw_custody_score_grouped.groupby(level=0).apply(lambda x:
                                                 100 * x / float(x.sum()))
raw_custody_score_grouped
# Out:
#                                ScoreText
# CustodyStatus       ScoreText
# Jail Inmate         High       12.418648
#                     Low        65.878603
#                     Medium     21.702749
# Parole              High       19.047619
#                     Low        52.380952
#                     Medium     28.571429
# Pretrial Defendant  High       14.631593
#                     Low        63.630415
#                     Medium     21.737992
# Prison Inmate       High       13.333333
#                     Low        60.000000
#                     Medium     26.666667
# Probation           High        8.464824
#                     Low        72.944817
#                     Medium     18.590358
# Residential Program High       26.984127
#                     Low        47.619048
#                     Medium     25.396825

# %% [markdown]
# ## Distribution of Agencies

# %%
raw_agency = compas_raw.loc[:,["Agency_Text"]]
raw_agency_grouped = raw_agency.groupby(["Agency_Text"]).size().reset_index()
raw_agency_grouped.columns = ["Agency_Text","count"]
raw_agency_grouped
# Out:
#       Agency_Text  count
# 0  Broward County    123
# 1            DRRD    564
# 2        PRETRIAL  41100
# 3       Probation  19056

# %% [markdown]
# ## Distribution of Assessment Reasons

# %%
raw_reason = compas_raw.loc[:,["AssessmentReason"]]
raw_reason_grouped = raw_reason.groupby(["AssessmentReason"]).size().reset_index()
raw_reason_grouped.columns = ["AssessmentReason","count"]
raw_reason_grouped
# Out:
#   AssessmentReason  count
# 0           Intake  60843

# %% [markdown]
# __`compas_two_year.csv`__

# %%
compas_two_year = pd.read_csv('data/compas-scores-two-years.csv')
compas_two_year_violent = pd.read_csv('data/compas-scores-two-years-violent.csv')

# %%
for i in range(4000):
    if compas_two_year_violent['id'][i] not in compas_two_year['id'].tolist():
        print(compas_two_year_violent['id'][i])
# Out:
# 3708
# 4995
# 6283
# 7132
# 8766

# %%
compas_two_year.shape
# Out:
# (7214, 53)

# %% [markdown]
# __`compas_two_year_violent.csv`__

# %%
compas_two_year_violent = pd.read_csv('data/compas-scores-two-years-violent.csv')
compas_two_year_violent.head()
# Out:
#    id                name   first         last compas_screening_date   sex  \
# 0   1    miguel hernandez  miguel    hernandez            2013-08-14  Male
# 1   3         kevon dixon   kevon        dixon            2013-01-27  Male
# 2   5         marcu brown   marcu        brown            2013-01-13  Male
# 3   6  bouthy pierrelouis  bouthy  pierrelouis            2013-03-26  Male
# 4   7        marsha miles  marsha        miles            2013-11-30  Male
#
#           dob  age          age_cat              race  juv_fel_count  \
# 0  1947-04-18   69  Greater than 45             Other              0
# 1  1982-01-22   34          25 - 45  African-American              0
# 2  1993-01-21   23     Less than 25  African-American              0
# 3  1973-01-22   43          25 - 45             Other              0
# 4  1971-08-22   44          25 - 45             Other              0
#
#    decile_score  juv_misd_count  juv_other_count  priors_count  \
# ...

# %%
compas_two_year_violent.shape
# Out:
# (4743, 54)

# %% [markdown]
# ## Graphing age, sex, and race

# %%
violent_sex = compas_two_year_violent.loc[:,["sex"]]
violent_sex_grouped = violent_sex.groupby(["sex"]).size().reset_index()
violent_sex_grouped.columns = ["sex","count"]
violent_sex_grouped
# Out:
#       sex  count
# 0  Female    997
# 1    Male   3746

# %%
sns.distplot(compas_two_year_violent['age'], bins=10)
plt.xlabel('Age')
plt.ylabel('Frequency');

# %%
age_cat_grouped = compas_two_year_violent.groupby(["age_cat"]).size().reset_index()
age_cat_grouped.columns = ["age_cat","count"]
sns.barplot(y = 'age_cat', x = 'count', data = age_cat_grouped);

# %%
race_grouped = compas_two_year_violent.groupby(["race"]).size().reset_index()
race_grouped.columns = ["race","count"]
sns.barplot(y = 'race', x = 'count', data = race_grouped.sort_values('count', ascending=False));

# %% [markdown]
# # Applying `Aequitas` for some initial results

# %%
compas_two_year.head()
# Out:
#    id                name   first         last compas_screening_date   sex  \
# 0   1    miguel hernandez  miguel    hernandez            2013-08-14  Male
# 1   3         kevon dixon   kevon        dixon            2013-01-27  Male
# 2   4            ed philo      ed        philo            2013-04-14  Male
# 3   5         marcu brown   marcu        brown            2013-01-13  Male
# 4   6  bouthy pierrelouis  bouthy  pierrelouis            2013-03-26  Male
#
#           dob  age          age_cat              race  juv_fel_count  \
# 0  1947-04-18   69  Greater than 45             Other              0
# 1  1982-01-22   34          25 - 45  African-American              0
# 2  1991-05-14   24     Less than 25  African-American              0
# 3  1993-01-21   23     Less than 25  African-American              0
# 4  1973-01-22   43          25 - 45             Other              0
#
#    decile_score  juv_misd_count  juv_other_count  priors_count  \
# ...

# %% [markdown]
# __We selected sex, age, and race as the attributes in question:__

# %%
df_eq = compas_two_year.loc[:, ['two_year_recid', 'decile_score', 'sex', 'age_cat', 'race']]
df_eq = df_eq.rename({'two_year_recid': 'label_value', 'decile_score': 'score'}, axis='columns')
df_eq.head()
# Out:
#    label_value  score   sex          age_cat              race
# 0            0      1  Male  Greater than 45             Other
# 1            1      3  Male          25 - 45  African-American
# 2            1      4  Male     Less than 25  African-American
# 3            0      8  Male     Less than 25  African-American
# 4            0      1  Male          25 - 45             Other

# %%
df_eq.to_csv('df_eq.csv')

# %% [markdown]
# We ran `Aequitas` from command line and obtained the result.

# %%
df_eq_aequitas = pd.read_csv('df_eq_aequitas.csv')

# %% [markdown]
# __Because the actions to take is punitive, we are interested in false positive rate parity.__
#
# We select `male` as the reference. The acceptable 80% to 120% interval is marked by the red lines:

# %%
sns.barplot(x='fpr', y='attribute_value', data=df_eq_aequitas.loc[4:5, ['attribute_value', 'fpr']])
plt.axvline(df_eq_aequitas.loc[5, 'fpr'] * 0.8, c='r')
plt.axvline(df_eq_aequitas.loc[5, 'fpr'] * 1.2, c='r')
plt.xlabel('False Positive Rate')
plt.ylabel('Sex');

# %% [markdown]
# For age, we select `25-45` as the reference:

# %%
sns.barplot(x='fpr', y='attribute_value', data=df_eq_aequitas.loc[6:8, ['attribute_value', 'fpr']])
plt.axvline(df_eq_aequitas.loc[6, 'fpr'] * 0.8, c='r')
plt.axvline(df_eq_aequitas.loc[6, 'fpr'] * 1.2, c='r')
plt.xlabel('False Positive Rate')
plt.ylabel('Age');

# %% [markdown]
# We select `Caucasian` for reference for race:

# %%
sns.barplot(x='fpr', y='attribute_value', data=df_eq_aequitas.loc[9:, ['attribute_value', 'fpr']])
plt.axvline(df_eq_aequitas.loc[11, 'fpr'] * 0.8, c='r')
plt.axvline(df_eq_aequitas.loc[11, 'fpr'] * 1.2, c='r')
plt.xlabel('False Positive Rate')
plt.ylabel('Race');

# %% [markdown]
# __Sadly, none of them pass the audit.__

# %% [markdown]
# ## We repeat the audit for the risk of violence assessment.

# %%
compas_two_year_violent.head()
# Out:
#    id                name   first         last compas_screening_date   sex  \
# 0   1    miguel hernandez  miguel    hernandez            2013-08-14  Male
# 1   3         kevon dixon   kevon        dixon            2013-01-27  Male
# 2   5         marcu brown   marcu        brown            2013-01-13  Male
# 3   6  bouthy pierrelouis  bouthy  pierrelouis            2013-03-26  Male
# 4   7        marsha miles  marsha        miles            2013-11-30  Male
#
#           dob  age          age_cat              race  juv_fel_count  \
# 0  1947-04-18   69  Greater than 45             Other              0
# 1  1982-01-22   34          25 - 45  African-American              0
# 2  1993-01-21   23     Less than 25  African-American              0
# 3  1973-01-22   43          25 - 45             Other              0
# 4  1971-08-22   44          25 - 45             Other              0
#
#    decile_score  juv_misd_count  juv_other_count  priors_count  \
# ...

# %%
df_eq_violent = compas_two_year.loc[:, ['is_violent_recid', 'v_decile_score', 'sex', 'age_cat', 'race']]
df_eq_violent = df_eq.rename({'is_violent_recid': 'label_value', 'v_decile_score': 'score'}, axis='columns')
df_eq_violent.head()
# Out:
#    label_value  score   sex          age_cat              race
# 0            0      1  Male  Greater than 45             Other
# 1            1      3  Male          25 - 45  African-American
# 2            1      4  Male     Less than 25  African-American
# 3            0      8  Male     Less than 25  African-American
# 4            0      1  Male          25 - 45             Other

# %%
df_eq_violent.to_csv('df_eq_violent.csv')

# %% [markdown]
# We ran `Aequitas` from command line and obtained the result.

# %%
df_eq_violent_aequitas = pd.read_csv('df_eq_violent_aequitas.csv')

# %%
sns.barplot(x='fpr', y='attribute_value', data=df_eq_violent_aequitas.loc[4:5, ['attribute_value', 'fpr']])
plt.axvline(df_eq_aequitas.loc[5, 'fpr'] * 0.8, c='r')
plt.axvline(df_eq_aequitas.loc[5, 'fpr'] * 1.2, c='r')
plt.xlabel('False Positive Rate')
plt.ylabel('Sex');

# %%
sns.barplot(x='fpr', y='attribute_value', data=df_eq_violent_aequitas.loc[6:8, ['attribute_value', 'fpr']])
plt.axvline(df_eq_aequitas.loc[6, 'fpr'] * 0.8, c='r')
plt.axvline(df_eq_aequitas.loc[6, 'fpr'] * 1.2, c='r')
plt.xlabel('False Positive Rate')
plt.ylabel('Age');

# %%
sns.barplot(x='fpr', y='attribute_value', data=df_eq_violent_aequitas.loc[9:, ['attribute_value', 'fpr']])
plt.axvline(df_eq_aequitas.loc[11, 'fpr'] * 0.8, c='r')
plt.axvline(df_eq_aequitas.loc[11, 'fpr'] * 1.2, c='r')
plt.xlabel('False Positive Rate')
plt.ylabel('Race');

# %% [markdown]
# __Again, all of them fail the audit.__
